# %% [markdown]
# ## GRIP - Data Science And Buisness Analytics

# %% [markdown]
# ### Name- Pradnya Mali

# %% [markdown]
# ## Task-3: Exploratory Data Analysis - Retail

# %% [raw]
# ### steps:
# 1.Read input data.
# 2.Store in DataFrame
# 3.Data cleaning
# 4.EDA

# %% [markdown]
# # Import the libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read the File

# %%
df=pd.read_csv('SampleSuperstore.csv')

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# # Show head and tail

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# # check Size and Shape

# %%
df.size
# Out:
# 129922

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# # check the information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [raw]
# The Retail dataset shows 9994 instances and 13 features.There are 2 features are integer and 3 features are float, objects are 8 features. The target column is Profit.

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# # calculate the unique values

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# # Data Visulisation

# %% [markdown]
# ### check the sqewness
# #### 1.Bar ploot
# #### 2.hist plot
# #### 3.dist plot

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## Distplot

# %%
fig=plt.figure()

# %%
fig,axes = plt.subplots(2,2,figsize=(18,9))
fig.suptitle('Distribution Plots',fontsize=18)
sns.distplot(df['Sales'],ax=axes[0,0])
sns.distplot(df['Discount'],ax=axes[0,1])
sns.distplot(df['Quantity'],ax=axes[1,0])
sns.distplot(df['Profit'],ax=axes[1,1])
plt.show;

# %% [raw]
# conclusion: Profit is normally Distributed
#             Sales is a Right squwed and positive squwed.

# %% [markdown]
# ## Hist plot

# %%
plt.hist(df['Quantity']);

# %% [raw]
# conclusion: Hist plot shows quantity data is right sqwed.

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# #### done by
# #### 1.heat map
# #### 2.pairplot
# #### 3.box plot
# #### 4.violin plot

# %%
df.corr() # show correlation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ## Heatmap

# %%
### show the corrleation by the visualisation

# %%
sns.heatmap(df.corr(),annot=True);

# %% [raw]
# Conclusion: Sales gives highest correaltion upto 0.48 near to 1.

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df,height=4,aspect=1);

# %% [raw]
# conclusion : Sales gives linear corrlation with Profit

# %%
## Box plot

# %%
df.plot(kind='box', figsize=(12,12), layout=(3,3), sharex=False, subplots=True);

# %% [raw]
# conclusion: Boxplot when used generally to check the Outliers.Profit,Sales,Quantity,Postal code shows the outliers.

# %% [markdown]
# ## Summary of conclusion from Data Visualisation.
# ### A) Univariate analyis:
# #### 1.dist plot and hist plot show the squwness of data.
# #### 2. Profit is normally Distributed and Sales shows highest positive squwed data.
# ### B). Bivariate Analysis:
# #### 1.Pairplot, Heatmap shows the linearity of the data
# #### 2. Sales shows highest corrlation with Profit
# #### 3. boxplot cheks the outliers of data and The five-number summary is the minimum, first quartile, median, third quartile, and maximum.
# #### 4.Profit,Sales,Quantity,Postal code shows the outliers.

# %% [markdown]
# # some important things got from data:

# %% [markdown]
# # Data Cleaning

# %% [raw]
# 1. Removing of Outliers.
# 2. Handle missing values
# 4. Remove duplicate or irrelevant observations.

# %% [markdown]
# ## Removing the Outliers
# 1. Z_Score
# 2. IQR range

# %%
### Outliers removed by  IQR method

# %%
for colname,colvals in df.iteritems():
    if df[colname].dtype!=object and colname!='Profit':
        Q1=df[colname].quantile(q=0.25)
        Q3=df[colname].quantile(q=0.75)
        IQR=Q3-Q1
        low=Q1-(1.5*IQR)
        up=Q3+(1.5*IQR)
        df.loc[(df[colname]<low) | (df[colname]>up) ,colname]=df[colname].median()
    else:
        continue

# %%
sns.boxplot(df['Sales']);

# %%
sns.boxplot(df['Quantity']);

# %%
sns.boxplot(df['Discount']);

# %%
# Handle missing valuees

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   float64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [raw]
# Conclusion: Data cant show missing values so no need to handle.

# %% [markdown]
# # cheking Duplicates of data

# %%
df.duplicated().sum()
# Out:
# 0

# %%
### droping duplicates values
df.drop_duplicates(inplace=True)

# %%
retail_data=df.drop(['Country','City','Postal Code'], axis=1)

# %%
retail_data.head()
# Out:
#         Ship Mode    Segment       State Region         Category Sub-Category  \
# 0    Second Class   Consumer    Kentucky  South        Furniture    Bookcases
# 1    Second Class   Consumer    Kentucky  South        Furniture       Chairs
# 2    Second Class  Corporate  California   West  Office Supplies       Labels
# 3  Standard Class   Consumer     Florida  South        Furniture       Tables
# 4  Standard Class   Consumer     Florida  South  Office Supplies      Storage
#
#       Sales  Quantity  Discount    Profit
# 0  261.9600         2      0.00   41.9136
# 1  731.9400         3      0.00  219.5820
# 2   14.6200         2      0.00    6.8714
# 3  957.5775         5      0.45 -383.0310
# 4   22.3680         2      0.20    2.5164

# %%
retail_data.shape
# Out:
# (9977, 10)

# %% [raw]
# Conclusion: we delete 'Country','City','Postal Code' these features as the informaton not much usefulto make data analysis.

# %% [markdown]
# # Inclusion of new Features :
# ### 1.Net Sales= Gross Sales - Discount
# ### 2.cost

# %%
def net_sales(retail_data):
    net_sales=retail_data['Sales'] * (1-retail_data['Discount'])
    return net_sales
retail_data['Net Sales']= retail_data.apply(net_sales, axis=1)

# %%
retail_data.head()
# Out:
#         Ship Mode    Segment       State Region         Category Sub-Category  \
# 0    Second Class   Consumer    Kentucky  South        Furniture    Bookcases
# 1    Second Class   Consumer    Kentucky  South        Furniture       Chairs
# 2    Second Class  Corporate  California   West  Office Supplies       Labels
# 3  Standard Class   Consumer     Florida  South        Furniture       Tables
# 4  Standard Class   Consumer     Florida  South  Office Supplies      Storage
#
#       Sales  Quantity  Discount    Profit   Net Sales
# 0  261.9600         2      0.00   41.9136  261.960000
# 1  731.9400         3      0.00  219.5820  731.940000
# 2   14.6200         2      0.00    6.8714   14.620000
# 3  957.5775         5      0.45 -383.0310  526.667625
# 4   22.3680         2      0.20    2.5164   17.894400

# %% [raw]
# # cost
# cost= net sales-profit
# profit = net sales -cost

# %%
def Cost(retail_data):
    Cost=retail_data['Net Sales'] - (retail_data['Profit'])
    return Cost
retail_data['Cost']= retail_data.apply(Cost, axis=1)

# %%
retail_data.head()
# Out:
#         Ship Mode    Segment       State Region         Category Sub-Category  \
# 0    Second Class   Consumer    Kentucky  South        Furniture    Bookcases
# 1    Second Class   Consumer    Kentucky  South        Furniture       Chairs
# 2    Second Class  Corporate  California   West  Office Supplies       Labels
# 3  Standard Class   Consumer     Florida  South        Furniture       Tables
# 4  Standard Class   Consumer     Florida  South  Office Supplies      Storage
#
#       Sales  Quantity  Discount    Profit   Net Sales        Cost
# 0  261.9600         2      0.00   41.9136  261.960000  220.046400
# 1  731.9400         3      0.00  219.5820  731.940000  512.358000
# 2   14.6200         2      0.00    6.8714   14.620000    7.748600
# 3  957.5775         5      0.45 -383.0310  526.667625  909.698625
# 4   22.3680         2      0.20    2.5164   17.894400   15.378000

# %% [markdown]
# # visualisation shows ship mode vs net sales.

# %%
retail_data.groupby('Ship Mode')['Cost'].sum().plot.bar(color= 'green')
# Out:
# <AxesSubplot:xlabel='Ship Mode'>

# %% [raw]
# Conclusion: Maximum sales takes place in Standard Class and minimun same day.

# %% [markdown]
# # Segment Distribution on basis of Profit.

# %%
retail_data.groupby('Segment')['Profit'].sum().plot.bar(color='brown')
plt.show()

# %%
Conclusion: Consumer shows highest ratio related to Profit.

# %% [markdown]
# # Regional Distribution and Net sales comparison alogwith Profit

# %%
retail_data.groupby('Region')['Net Sales'].sum().plot(kind= 'pie', autopct='%.1f%%',pctdistance=0.5)
plt.show()

# %%
retail_data.groupby('Region')['Profit'].sum().plot(kind= 'pie', autopct='%.1f%%',pctdistance=0.5)
plt.show()

# %%
Conclusion: west region its gives best profit to retail data.

# %% [markdown]
# # State Distribution and Net sales comparison alogwith Profit

# %%
retail_data.groupby('State')[['Net Sales', 'Profit']].sum().sort_values(by='Profit',
            ascending =True).plot(kind='bar', figsize=(13,9),color= ['blue','red'])
plt.show()

# %% [raw]
# Conclusion: California,newyork and Washington gives higher profit with proper sales , gives more attention to them on left side areas sales is huge but no profit visible.

# %% [markdown]
# # Net Sales from diffrent category

# %%
retail_data['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
retail_data.groupby('Category')['Net Sales'].sum().plot.bar(color='purple')
# Out:
# <AxesSubplot:xlabel='Category'>

# %%
retail_data.groupby('Category')['Profit'].sum().plot.bar(color='purple')
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [raw]
# Conclusion: These both Net sales and Proft shows huge difference net sales of furniture is high than compared to Profit but office suppliers and technology is same.

# %%
retail_data.groupby('Sub-Category')[['Net Sales', 'Profit']].sum().sort_values(by='Profit',
            ascending =True).plot(kind='barh', figsize=(13,9),color= ['Violet','Purple'])
plt.show()

# %% [raw]
# Conclusions: Copiers, Phones, Accesaries gives good profit With proper sales whereas suppliers bookcases,Tables making a loss.

# %% [markdown]
# # comparison of Net sales and Profit

# %%
sns.kdeplot(data=retail_data['Net Sales'],color='red')
sns.kdeplot(data=retail_data['Profit'],color='Blue')
plt.xlim(-500,2000)
plt.show()

# %% [raw]
# Conclusion: Profit is more in comparision to Net Sales.

# %% [markdown]
# # comparison of Net sales and cost

# %%
sns.kdeplot(data=retail_data['Net Sales'],color='red')
sns.kdeplot(data=retail_data['Cost'],color='Blue')
plt.xlim(-500,2000)
plt.show()

# %% [raw]
# Conclusion: Net Sales is associated in alignment with cost.

# %% [markdown]
# # summary and conclusion of visualisations

# %% [markdown]
# ### 1.More focus on central and South zones.
# ### 2.sales likes cities Texas ,Ohio etc. gives good sales bt no profit.
# ### 3.Gives more imp to technology and suppliers Sector they performing well.
# ### 4.Finally resourses must be optimised wastages are reduce so reduction in ovverall cost maximize sales.

# %% [markdown]
# # Thank You
